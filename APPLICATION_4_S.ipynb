# %% [markdown]
# ![image.png](attachment:2498925e-1232-4837-a6f8-732d78d4ed99.png)

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from sklearn import preprocessing
from matplotlib import pyplot as plt
from statsmodels.tsa.stattools import adfuller, coint
from Kalman_Random_Walk import Kalman_RW as DLF
from Kalman_LLT import Kalman_LLT as LLT

# %% [markdown]
# Import Data

# %%
DATA = np.array(pd.read_excel('PEPSI_COLA.xlsx', 'data', usecols='B:C'))
PEPSI=DATA[1600:,0]
COCA=DATA[1600:,1]
